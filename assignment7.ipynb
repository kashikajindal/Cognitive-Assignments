# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Part I: Randomized Sales Data Generation

# Step 1: Initialize Random Seed 
roll_number = 102317154 
np.random.seed(roll_number)

# Step 2: Generate Sales Data
sales_data = np.random.randint(1000, 5001, size=(12, 4))

# Step 3: Convert to DataFrame
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
sales_df = pd.DataFrame(sales_data, columns=categories, index=months)

# Part II: Data Manipulation and Analysis

# Step 1: Display first 5 rows and summary statistics
print(sales_df.head())
print(sales_df.describe())
# Step 2: Calculate total sales per category and per month
total_sales_per_category = sales_df.sum()
total_sales_per_month = sales_df.sum(axis=1)

# Step 3: Calculate average sales growth
growth_rate = sales_df.pct_change().mean()

# Step 4: Add new columns
sales_df['Total Sales'] = total_sales_per_month
sales_df['Growth Rate'] = sales_df['Total Sales'].pct_change() * 100

# Step 5: Apply discount based on roll number
if roll_number % 2 == 0:
    sales_df['Electronics'] *= 0.9  # 10% discount
else:
    sales_df['Clothing'] *= 0.85  # 15% discount

print("\nSales data after discount:")
print(sales_df)

# Part III: Visualizations

# Line plot for monthly sales trends
sales_df[categories].plot(marker='o', figsize=(10, 6))
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend(title='Category')
plt.grid()
plt.show()
# Box plot for sales distribution
plt.figure(figsize=(8, 5))
sns.boxplot(data=sales_df[categories])
plt.title('Sales Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4595      3686            2436    4521
# Feb         4991      3155            4224    1539
# Mar         2097      2852            4639    2651
# Apr         2523      4293            1498    4300
# May         2667      4782            2954    4357
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2983.416667  3204.000000     2870.250000  3259.750000
# std    1351.209388  1245.577413     1363.396236  1032.037361
# min    1355.000000  1125.000000     1163.000000  1539.000000
# 25%    1937.750000  2531.750000     1708.000000  2332.500000
# 50%    2674.500000  3420.500000     2695.000000  3359.000000
# 75%    4442.750000  4044.750000     4255.250000  4314.250000
# max    4991.000000  4782.000000     4922.000000  4586.000000
#
# Sales data after discount:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       4135.5      3686            2436    4521        15238          NaN
# Feb       4491.9      3155            4224    1539        13909    -8.721617
# Mar       1887.3      2852            4639    2651        12239   -12.006614
# Apr       2270.7      4293            1498    4300        12614     3.063976
# May       2400.3      4782            2954    4357        14760    17.012843
# Jun       2413.8      1571            3098    2304         9655   -34.586721
# Jul       2693.7      4661            1163    4586        13403    38.819265
# Aug       1219.5      2887            1504    3392         9138   -31.821234
# Sep       1314.0      3922            4349    3496        13227    44.747209
# Oct       4186.8      1125            4922    3326        14025     6.033114
# Nov       1254.6      1552            1880    2342         7168   -48.891266
# Dec       3952.8      3962            1776    2303        12433    73.451451

# %%
# Q2: Element-wise operations on array
array = np.array([[1, -2, 3], [-4, 5, -6]])
print("Absolute Values:\n", np.abs(array))

# Percentiles
print("Percentiles (Flattened):", np.percentile(array, [25, 50, 75]))
print("Percentiles (Columns):", np.percentile(array, [25, 50, 75], axis=0))
print("Percentiles (Rows):", np.percentile(array, [25, 50, 75], axis=1))

# Mean, Median, Standard Deviation
print("Mean:", np.mean(array))
print("Median:", np.median(array))
print("Standard Deviation:", np.std(array))
# Out:
# Absolute Values:
#  [[1 2 3]
#  [4 5 6]]
# Percentiles (Flattened): [-3.5 -0.5  2.5]
# Percentiles (Columns): [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# Percentiles (Rows): [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224

# %%
# Q3: Floor, Ceiling, Truncate, Round
arr = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print("Floor:", np.floor(arr))
print("Ceiling:", np.ceil(arr))
print("Truncate:", np.trunc(arr))
print("Rounded:", np.round(arr))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncate: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %%
# Q4: Swap elements in list using a temporary variable
def swap_list_elements(lst, i, j):
    temp = lst[i]
    lst[i] = lst[j]
    lst[j] = temp
    return lst

my_list = [1, 2, 3, 4, 5]
print("Swapped List:", swap_list_elements(my_list, 1, 3))
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %%
ex_set = {1, 2, 3, 4, 5}
ex_list = list(ex_set)
ex_list[0], ex_list[1] = ex_list[1], ex_list[0]
ex_set = set(ex_list)
print("Swapped Set:", ex_set)
# Out:
# Swapped Set: {1, 2, 3, 4, 5}
